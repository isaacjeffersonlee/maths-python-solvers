# %% [markdown]
# # Matrix Solver Jupyter Version
# Author: Isaac Lee
#
# #### How to use
# See option [14].

# %%
from solver_functions import *
init_printing(use_latex=True) # Set this to False if all you care about in life is speed.

# %%
main(using_jupyter=True)
# Out:
# System of ODEs Solver: dY/dt = A*Y + g(t)
#
# Independent variable, i.e t: t
#
# Matrix A:
#
# Use a saved matrix? y/n n
#
# New Matrix:
# No. Rows: 2
# No. Cols: 2
# Input each row as a space seperated list of the elements.
# E.g: 1 0 0 0 -1 0
# Row 1: 1 1/2
# Row 2: 2 -1
# ⎡1  1/2⎤
# ⎢      ⎥
# ⎣2  -1 ⎦
# Input dependent variables, i.e x, y, z:
# Variable 1: x
# [x(t)]
# Variable 2: y
# [x(t), y(t)]
#
# Non-homogenous part vector g(t):
# g(t) row 1 entry: 0
# g(t) row 2 entry: 0
#
# Warning: This could hang if the eigenvectors are not easily found.
#
# (Eigenvalue, [Algebraic Multiplicity], Eigenspace Basis):
# ⎡⎛          ⎡⎡1   √2⎤⎤⎞  ⎛         ⎡⎡1   √2⎤⎤⎞⎤
# ⎢⎜          ⎢⎢─ - ──⎥⎥⎟  ⎜         ⎢⎢─ + ──⎥⎥⎟⎥
# ⎢⎜-√2, [1], ⎢⎢2   2 ⎥⎥⎟, ⎜√2, [1], ⎢⎢2   2 ⎥⎥⎟⎥
# ⎢⎜          ⎢⎢      ⎥⎥⎟  ⎜         ⎢⎢      ⎥⎥⎟⎥
# ⎣⎝          ⎣⎣  1   ⎦⎦⎠  ⎝         ⎣⎣  1   ⎦⎦⎠⎦
# Matrix is diagonalizable!
# P D P**-1 == A:
# ⎡                             ⎡-1 + √2      1     ⎤          ⎤
# ⎢                             ⎢───────  ──────────⎥          ⎥
# ⎢⎡1   √2  1   √2⎤             ⎢-2 + √2    ⎛    √2⎞⎥          ⎥
# ⎢⎢─ - ──  ─ + ──⎥  ⎡-√2  0 ⎤  ⎢         4⋅⎜1 - ──⎟⎥  ⎡1  1/2⎤⎥
# ⎢⎢2   2   2   2 ⎥, ⎢       ⎥, ⎢           ⎝    2 ⎠⎥, ⎢      ⎥⎥
# ⎢⎢              ⎥  ⎣ 0   √2⎦  ⎢                   ⎥  ⎣2  -1 ⎦⎥
# ⎢⎣  1       1   ⎦             ⎢  √2       1   √2  ⎥          ⎥
# ⎢                             ⎢  ──       ─ - ──  ⎥          ⎥
# ⎣                             ⎣  2        2   4   ⎦          ⎦
# Solutions:
# ⎡       ⎛                           2⋅√2⋅t⎞  -√2⋅t⎤
# ⎢       ⎝C₁⋅(1 - √2) + C₂⋅(1 + √2)⋅ℯ      ⎠⋅ℯ     ⎥
# ⎢x(t) = ──────────────────────────────────────────⎥
# ⎢                           2                     ⎥
# ⎢                                                 ⎥
# ⎢                      -√2⋅t       √2⋅t           ⎥
# ⎣           y(t) = C₁⋅ℯ      + C₂⋅ℯ               ⎦
# Trace: 0
# Determinant: -2
# $\displaystyle \Delta < 0$
# Saddle-point or Hyperbolic profile:
#     Warning: This image is not a plot, rather just a screenshot from the notes
#     from the correct quadrant. This is to give a general indication of the
#     general shape of the phase portrait for this (det, trace) quadrant.
#
#
#
# Options:
# [0]. Return to main menu
# [1]. System of ODEs Solver
# [2]. Singular ODE Solver

# %%
Image(filename="Images/chad.png")
