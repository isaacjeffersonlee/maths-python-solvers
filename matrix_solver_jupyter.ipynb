# %% [markdown]
# # Matrix Solver Jupyter Version
# Author: Isaac Lee
#
# #### How to use
# See option [14].

# %%
from solver_functions import *
init_printing(use_latex=True) # Set this to False if all you care about in life is speed.
plt.rcParams["figure.figsize"]=10, 10 # The size of plots

# %%
main(using_jupyter=True)
# Out:
# ___  ___      _        _        _____       _
# |  \/  |     | |      (_)      /  ___|     | |
# | .  . | __ _| |_ _ __ ___  __ \ `--.  ___ | |_   _____ _ __
# | |\/| |/ _` | __| '__| \ \/ /  `--. \/ _ \| \ \ / / _ \ '__|
# | |  | | (_| | |_| |  | |>  <  /\__/ / (_) | |\ V /  __/ |
# \_|  |_/\__,_|\__|_|  |_/_/\_\ \____/ \___/|_| \_/ \___|_|
#
# Author: Isaac Lee
#
#
#
# Available Operations:
# [0].  Quit
# [1].  Multiply Matrices
# [2].  Inverse
# [3].  Transpose
# [4].  Determinant
# [5].  Row reduce to echelon form
# [6].  Basis for left and right nullspace
# [7].  Rank and Basis for Row space and Column space
# [8].  Eigenvalues and Eigenvectors
# [9].  Diagonalize/Jordan Normal
# [10]. Delete rows/cols
# [11]. Applied Maths Mode
# [12]. Calculus Mode: Differential Equations
# [13]. Save/Load matrices from file
# [14]. How To guide
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-26f465e47d5f> in <module>
# ----> 1 main(using_jupyter=True)
#
# ~/Projects/Python/Maths/Solvers/solver_functions.py in main(using_jupyter)
#    1402         solver.clear_previous()
#    1403         print(title_text)
# -> 1404         mode_num = solver.mode_selector()
#    1405         try:
#    1406             if mode_num == 0:
#
# ~/Projects/Python/Maths/Solvers/solver_functions.py in mode_selector(self)
#     344         while True:
#     345             try:
# --> 346                 mode_choice = int(input("Mode No.: "))
#     347                 if mode_choice in available_nums:
#     348                     return mode_choice
#
# ~/Projects/Python/Maths/Solvers/env/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     846                 "raw_input was called, but this frontend does not support input requests."
#     847             )
# --> 848         return self._input_request(str(prompt),
#     849             self._parent_ident,
#     850             self._parent_header,
#
# ~/Projects/Python/Maths/Solvers/env/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
Image(filename="Images/chad.png")
